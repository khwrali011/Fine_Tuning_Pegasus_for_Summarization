# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_excel("/content/drive/MyDrive/2000calls_dataset.xlsx")

# %%
df.describe()
# Out:
#                                            Transcriptions  \
# count                                                1999
# unique                                               1997
# top     Hi, this is telespecialist, how can I help you...
# freq                                                    3
#
#                                       Summary
# count                                    1999
# unique                                   1980
# top     There is no call summary to generate.
# freq                                        5

# %%
df = df.drop_duplicates()
df = df.dropna()
df.describe()
# Out:
#                                            Transcriptions  \
# count                                                1999
# unique                                               1997
# top     Hi, this is telespecialist, how can I help you...
# freq                                                    3
#
#                                       Summary
# count                                    1999
# unique                                   1980
# top     There is no call summary to generate.
# freq                                        5

# %%
from sklearn.model_selection import train_test_split
# Split the DataFrame
train_df, test_df = train_test_split(df, test_size=0.1, random_state=42)

# Save to CSV files
train_df.to_csv('/content/data/train.csv', index=False)
test_df.to_csv('/content/data/test.csv', index=False)

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !huggingface-cli repo create summary-dataset --type dataset
# Out:
# git version 2.34.1
# git-lfs/3.0.2 (GitHub; linux amd64; go 1.18.1)
#
# You are about to create datasets/khwrali011/summary-dataset
# Proceed? [Y/n] Y
#
# Your repo now lives at:
#   https://huggingface.co/datasets/khwrali011/summary-dataset
#
# You can clone it locally with the command below, and commit/push as usual.
#
#   git clone https://huggingface.co/datasets/khwrali011/summary-dataset

# %%
# !huggingface-cli upload summary-dataset ./data . --repo-type dataset
# Out:
# Consider using `hf_transfer` for faster uploads. This solution comes with some limitations. See https://huggingface.co/docs/huggingface_hub/hf_transfer for more details.
# https://huggingface.co/datasets/khwrali011/summary-dataset/tree/main/.

# %%
# !pip install datasets -q
from datasets import load_dataset
dataset_samsum = load_dataset("khwrali011/summary-dataset")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 31.4 MB/s eta 0:00:00
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
dataset_samsum
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Transcriptions', 'Summary'],
#         num_rows: 1799
#     })
#     test: Dataset({
#         features: ['Transcriptions', 'Summary'],
#         num_rows: 200
#     })
# })
